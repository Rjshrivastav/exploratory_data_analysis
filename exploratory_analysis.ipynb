# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data=pd.read_csv(r'C:\Users\Ranjeet shrivastav\Downloads\data_python\marketing_data.csv',index_col=0)

# %%
data
# Out:
#        Year_Birth   Education Marital_Status       Income  Kidhome  Teenhome  \
# ID
# 1826         1970  Graduation       Divorced  $84,835.00         0         0
# 1            1961  Graduation         Single  $57,091.00         0         0
# 10476        1958  Graduation        Married  $67,267.00         0         1
# 1386         1967  Graduation       Together  $32,474.00         1         1
# 5371         1989  Graduation         Single  $21,474.00         1         0
# ...           ...         ...            ...          ...      ...       ...
# 10142        1976         PhD       Divorced  $66,476.00         0         1
# 5263         1977    2n Cycle        Married  $31,056.00         1         0
# 22           1976  Graduation       Divorced  $46,310.00         1         0
# 528          1978  Graduation        Married  $65,819.00         0         0
# 4070         1969         PhD        Married  $94,871.00         0         2
#
# ...

# %%
data.columns
# Out:
# Index(['Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Response', 'Complain', 'Country'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Year_Birth               59
# Education                 5
# Marital_Status            8
# Income                 1974
# Kidhome                   3
# Teenhome                  3
# Dt_Customer             663
# Recency                 100
# MntWines                776
# MntFruits               158
# MntMeatProducts         558
# MntFishProducts         182
# MntSweetProducts        177
# MntGoldProds            213
# NumDealsPurchases        15
# NumWebPurchases          15
# NumCatalogPurchases      14
# NumStorePurchases        14
# NumWebVisitsMonth        16
# AcceptedCmp3              2
# AcceptedCmp4              2
# AcceptedCmp5              2
# AcceptedCmp1              2
# AcceptedCmp2              2
# Response                  2
# Complain                  2
# Country                   8
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2240 entries, 1826 to 4070
# Data columns (total 27 columns):
# Year_Birth             2240 non-null int64
# Education              2240 non-null object
# Marital_Status         2240 non-null object
# Income                 2216 non-null object
# Kidhome                2240 non-null int64
# Teenhome               2240 non-null int64
# Dt_Customer            2240 non-null object
# Recency                2240 non-null int64
# MntWines               2240 non-null int64
# MntFruits              2240 non-null int64
# MntMeatProducts        2240 non-null int64
# MntFishProducts        2240 non-null int64
# MntSweetProducts       2240 non-null int64
# MntGoldProds           2240 non-null int64
# NumDealsPurchases      2240 non-null int64
# NumWebPurchases        2240 non-null int64
# NumCatalogPurchases    2240 non-null int64
# NumStorePurchases      2240 non-null int64
# NumWebVisitsMonth      2240 non-null int64
# ...

# %%
data.describe()
# Out:
#         Year_Birth      Kidhome     Teenhome      Recency     MntWines  \
# count  2240.000000  2240.000000  2240.000000  2240.000000  2240.000000
# mean   1968.805804     0.444196     0.506250    49.109375   303.935714
# std      11.984069     0.538398     0.544538    28.962453   336.597393
# min    1893.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1959.000000     0.000000     0.000000    24.000000    23.750000
# 50%    1970.000000     0.000000     0.000000    49.000000   173.500000
# 75%    1977.000000     1.000000     1.000000    74.000000   504.250000
# max    1996.000000     2.000000     2.000000    99.000000  1493.000000
#
#          MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count  2240.000000      2240.000000      2240.000000       2240.000000
# mean     26.302232       166.950000        37.525446         27.062946
# std      39.773434       225.715373        54.628979         41.280498
# ...

# %%
market=data.drop(['AcceptedCmp3','AcceptedCmp4','AcceptedCmp5','AcceptedCmp1','AcceptedCmp2'],axis=1)

# %%
market
# Out:
#        Year_Birth   Education Marital_Status       Income  Kidhome  Teenhome  \
# ID
# 1826         1970  Graduation       Divorced  $84,835.00         0         0
# 1            1961  Graduation         Single  $57,091.00         0         0
# 10476        1958  Graduation        Married  $67,267.00         0         1
# 1386         1967  Graduation       Together  $32,474.00         1         1
# 5371         1989  Graduation         Single  $21,474.00         1         0
# ...           ...         ...            ...          ...      ...       ...
# 10142        1976         PhD       Divorced  $66,476.00         0         1
# 5263         1977    2n Cycle        Married  $31,056.00         1         0
# 22           1976  Graduation       Divorced  $46,310.00         1         0
# 528          1978  Graduation        Married  $65,819.00         0         0
# 4070         1969         PhD        Married  $94,871.00         0         2
#
# ...

# %%
market.columns
# Out:
# Index(['Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'Response', 'Complain', 'Country'],
#       dtype='object')

# %%
market['Total_Children']=market['Kidhome']+market['Teenhome']

# %%
market=market.drop(['Kidhome','Teenhome'],axis=1)

# %%
market
# Out:
#        Year_Birth   Education Marital_Status       Income Dt_Customer  \
# ID
# 1826         1970  Graduation       Divorced  $84,835.00      6/16/14
# 1            1961  Graduation         Single  $57,091.00      6/15/14
# 10476        1958  Graduation        Married  $67,267.00      5/13/14
# 1386         1967  Graduation       Together  $32,474.00   05-11-2014
# 5371         1989  Graduation         Single  $21,474.00   04-08-2014
# ...           ...         ...            ...          ...         ...
# 10142        1976         PhD       Divorced  $66,476.00   03-07-2013
# 5263         1977    2n Cycle        Married  $31,056.00      1/22/13
# 22           1976  Graduation       Divorced  $46,310.00   12-03-2012
# 528          1978  Graduation        Married  $65,819.00     11/29/12
# 4070         1969         PhD        Married  $94,871.00   09-01-2012
#
#        Recency  MntWines  MntFruits  MntMeatProducts  MntFishProducts  ...  \
# ...

# %%
market.nunique()
# Out:
# Year_Birth               59
# Education                 5
# Marital_Status            8
# Income                 1974
# Dt_Customer             663
# Recency                 100
# MntWines                776
# MntFruits               158
# MntMeatProducts         558
# MntFishProducts         182
# MntSweetProducts        177
# MntGoldProds            213
# NumDealsPurchases        15
# NumWebPurchases          15
# NumCatalogPurchases      14
# NumStorePurchases        14
# NumWebVisitsMonth        16
# Response                  2
# Complain                  2
# Country                   8
# Total_Children            4
# dtype: int64

# %%
market.describe()
# Out:
#         Year_Birth      Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2240.000000  2240.000000  2240.000000  2240.000000      2240.000000
# mean   1968.805804    49.109375   303.935714    26.302232       166.950000
# std      11.984069    28.962453   336.597393    39.773434       225.715373
# min    1893.000000     0.000000     0.000000     0.000000         0.000000
# 25%    1959.000000    24.000000    23.750000     1.000000        16.000000
# 50%    1970.000000    49.000000   173.500000     8.000000        67.000000
# 75%    1977.000000    74.000000   504.250000    33.000000       232.000000
# max    1996.000000    99.000000  1493.000000   199.000000      1725.000000
#
#        MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# count      2240.000000       2240.000000   2240.000000        2240.000000
# mean         37.525446         27.062946     44.021875           2.325000
# ...

# %%
market['Income'].dtype
# Out:
# dtype('O')

# %%
market['Income']=market['Income'].str.replace('$','').str.replace(',','').astype(float)

# %%
market['Income']
# Out:
# ID
# 1826     84835.0
# 1        57091.0
# 10476    67267.0
# 1386     32474.0
# 5371     21474.0
#           ...
# 10142    66476.0
# 5263     31056.0
# 22       46310.0
# 528      65819.0
# 4070     94871.0
# Name: Income, Length: 2240, dtype: float64

# %%
market.describe()
# Out:
#         Year_Birth         Income      Recency     MntWines    MntFruits  \
# count  2240.000000    2216.000000  2240.000000  2240.000000  2240.000000
# mean   1968.805804   52247.251354    49.109375   303.935714    26.302232
# std      11.984069   25173.076661    28.962453   336.597393    39.773434
# min    1893.000000    1730.000000     0.000000     0.000000     0.000000
# 25%    1959.000000   35303.000000    24.000000    23.750000     1.000000
# 50%    1970.000000   51381.500000    49.000000   173.500000     8.000000
# 75%    1977.000000   68522.000000    74.000000   504.250000    33.000000
# max    1996.000000  666666.000000    99.000000  1493.000000   199.000000
#
#        MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  \
# count      2240.000000      2240.000000       2240.000000   2240.000000
# mean        166.950000        37.525446         27.062946     44.021875
# std         225.715373        54.628979         41.280498     52.167439
# ...

# %%
market.isnull().sum()
# Out:
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Response                0
# Complain                0
# Country                 0
# Total_Children          0
# dtype: int64

# %%
market['Income']=market['Income'].fillna(market['Income'].mean())

# %%
market
# Out:
#        Year_Birth   Education Marital_Status   Income Dt_Customer  Recency  \
# ID
# 1826         1970  Graduation       Divorced  84835.0     6/16/14        0
# 1            1961  Graduation         Single  57091.0     6/15/14        0
# 10476        1958  Graduation        Married  67267.0     5/13/14        0
# 1386         1967  Graduation       Together  32474.0  05-11-2014        0
# 5371         1989  Graduation         Single  21474.0  04-08-2014        0
# ...           ...         ...            ...      ...         ...      ...
# 10142        1976         PhD       Divorced  66476.0  03-07-2013       99
# 5263         1977    2n Cycle        Married  31056.0     1/22/13       99
# 22           1976  Graduation       Divorced  46310.0  12-03-2012       99
# 528          1978  Graduation        Married  65819.0    11/29/12       99
# 4070         1969         PhD        Married  94871.0  09-01-2012       99
#
# ...

# %%
market.isnull().sum()
# Out:
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# Response               0
# Complain               0
# Country                0
# Total_Children         0
# dtype: int64

# %%
market['Dt_Customer']=pd.to_datetime(market['Dt_Customer'])

# %%
market['Dt_Customer']
# Out:
# ID
# 1826    2014-06-16
# 1       2014-06-15
# 10476   2014-05-13
# 1386    2014-05-11
# 5371    2014-04-08
#            ...
# 10142   2013-03-07
# 5263    2013-01-22
# 22      2012-12-03
# 528     2012-11-29
# 4070    2012-09-01
# Name: Dt_Customer, Length: 2240, dtype: datetime64[ns]

# %%
market.loc[market['Year_Birth']<1910]
# Out:
#        Year_Birth Education Marital_Status   Income Dt_Customer  Recency  \
# ID
# 11004        1893  2n Cycle         Single  60182.0  2014-05-17       23
# 1150         1899       PhD       Together  83532.0  2013-09-26       36
# 7829         1900  2n Cycle       Divorced  36640.0  2013-09-26       99
#
#        MntWines  MntFruits  MntMeatProducts  MntFishProducts  ...  \
# ID                                                            ...
# 11004         8          0                5                7  ...
# 1150        755        144              562              104  ...
# 7829         15          6                8                7  ...
#
#        MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ID
# 11004             2                  1                1                    0
# 1150            224                  1                4                    6
# 7829             25                  1                2                    1
#
# ...

# %%
market.drop(index=[11004,1150,7829],inplace=True)

# %%
market.loc[market['Year_Birth']<1910]
# Out:
# Empty DataFrame
# Columns: [Year_Birth, Education, Marital_Status, Income, Dt_Customer, Recency, MntWines, MntFruits, MntMeatProducts, MntFishProducts, MntSweetProducts, MntGoldProds, NumDealsPurchases, NumWebPurchases, NumCatalogPurchases, NumStorePurchases, NumWebVisitsMonth, Response, Complain, Country, Total_Children]
# Index: []
#
# [0 rows x 21 columns]

# %%
#checking for outliners
sns.boxplot(x='Education',y='Income',data=market)

# %%
market.loc[market.Income>600000]
# Out:
#       Year_Birth   Education Marital_Status    Income Dt_Customer  Recency  \
# ID
# 9432        1977  Graduation       Together  666666.0  2013-06-02       23
#
#       MntWines  MntFruits  MntMeatProducts  MntFishProducts  ...  \
# ID                                                           ...
# 9432         9         14               18                8  ...
#
#       MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ID
# 9432            12                  4                3                    1
#
#       NumStorePurchases  NumWebVisitsMonth  Response  Complain  Country  \
# ID
# 9432                  3                  6         0         0       SA
#
#      Total_Children
# ID
# 9432              1
#
# [1 rows x 21 columns]

# %%
#droping outliner
market.drop(index=9432,inplace=True)

# %%
market.loc[market.Income>600000]
# Out:
# Empty DataFrame
# Columns: [Year_Birth, Education, Marital_Status, Income, Dt_Customer, Recency, MntWines, MntFruits, MntMeatProducts, MntFishProducts, MntSweetProducts, MntGoldProds, NumDealsPurchases, NumWebPurchases, NumCatalogPurchases, NumStorePurchases, NumWebVisitsMonth, Response, Complain, Country, Total_Children]
# Index: []
#
# [0 rows x 21 columns]

# %%
sns.boxplot(x='Education',y='Income',data=market)

# %%
market.loc[market.Income>140000]
# Out:
#        Year_Birth   Education Marital_Status    Income Dt_Customer  Recency  \
# ID
# 4931         1977  Graduation       Together  157146.0  2013-04-29       13
# 1501         1982         PhD        Married  160803.0  2012-08-04       21
# 1503         1976         PhD       Together  162397.0  2013-06-03       31
# 5336         1971      Master       Together  157733.0  2013-06-04       37
# 5555         1975  Graduation       Divorced  153924.0  2014-02-07       81
# 11181        1949         PhD        Married  156924.0  2013-08-29       85
# 8475         1973         PhD        Married  157243.0  2014-03-01       98
#
#        MntWines  MntFruits  MntMeatProducts  MntFishProducts  ...  \
# ID                                                            ...
# 4931          1          0             1725                2  ...
# 1501         55         16             1622               17  ...
# 1503         85          1               16                2  ...
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig,axis=plt.subplots(1,2,figsize=(12,6))
sns.boxplot(x='Education',y='Income',data=market,ax=axis[0])


sns.boxplot(x='Country',y='Income',data=market,ax=axis[1])

# %%
market.nunique()
# Out:
# Year_Birth               56
# Education                 5
# Marital_Status            8
# Income                 1971
# Dt_Customer             663
# Recency                 100
# MntWines                775
# MntFruits               158
# MntMeatProducts         557
# MntFishProducts         182
# MntSweetProducts        177
# MntGoldProds            213
# NumDealsPurchases        15
# NumWebPurchases          15
# NumCatalogPurchases      14
# NumStorePurchases        14
# NumWebVisitsMonth        16
# Response                  2
# Complain                  2
# Country                   8
# Total_Children            4
# dtype: int64

# %%
market.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2236 entries, 1826 to 4070
# Data columns (total 21 columns):
# Year_Birth             2236 non-null int64
# Education              2236 non-null object
# Marital_Status         2236 non-null object
# Income                 2236 non-null float64
# Dt_Customer            2236 non-null datetime64[ns]
# Recency                2236 non-null int64
# MntWines               2236 non-null int64
# MntFruits              2236 non-null int64
# MntMeatProducts        2236 non-null int64
# MntFishProducts        2236 non-null int64
# MntSweetProducts       2236 non-null int64
# MntGoldProds           2236 non-null int64
# NumDealsPurchases      2236 non-null int64
# NumWebPurchases        2236 non-null int64
# NumCatalogPurchases    2236 non-null int64
# NumStorePurchases      2236 non-null int64
# NumWebVisitsMonth      2236 non-null int64
# Response               2236 non-null int64
# Complain               2236 non-null int64
# ...

# %%
market.corr()
# Out:
#                      Year_Birth    Income   Recency  MntWines  MntFruits  \
# Year_Birth             1.000000 -0.198889 -0.019396 -0.162809  -0.013657
# Income                -0.198889  1.000000  0.007963  0.685944   0.504859
# Recency               -0.019396  0.007963  1.000000  0.016321  -0.003717
# MntWines              -0.162809  0.685944  0.016321  1.000000   0.388472
# MntFruits             -0.013657  0.504859 -0.003717  0.388472   1.000000
# MntMeatProducts       -0.030729  0.684170  0.023446  0.561886   0.542030
# MntFishProducts       -0.042359  0.518381  0.001314  0.398956   0.594415
# MntSweetProducts      -0.019379  0.518161  0.022796  0.385845   0.567030
# MntGoldProds          -0.057419  0.383593  0.017168  0.386234   0.389999
# NumDealsPurchases     -0.068286 -0.107140 -0.000638  0.011173  -0.131792
# NumWebPurchases       -0.153873  0.450579 -0.010776  0.542136   0.296986
# NumCatalogPurchases   -0.125285  0.693660  0.025226  0.634716   0.487274
# ...

# %%
sns.heatmap(data=market.corr(),annot=False)

# %%
sns.pairplot(market)

# %%
market
# Out:
#        Year_Birth   Education Marital_Status   Income Dt_Customer  Recency  \
# ID
# 1826         1970  Graduation       Divorced  84835.0  2014-06-16        0
# 1            1961  Graduation         Single  57091.0  2014-06-15        0
# 10476        1958  Graduation        Married  67267.0  2014-05-13        0
# 1386         1967  Graduation       Together  32474.0  2014-05-11        0
# 5371         1989  Graduation         Single  21474.0  2014-04-08        0
# ...           ...         ...            ...      ...         ...      ...
# 10142        1976         PhD       Divorced  66476.0  2013-03-07       99
# 5263         1977    2n Cycle        Married  31056.0  2013-01-22       99
# 22           1976  Graduation       Divorced  46310.0  2012-12-03       99
# 528          1978  Graduation        Married  65819.0  2012-11-29       99
# 4070         1969         PhD        Married  94871.0  2012-09-01       99
#
# ...

# %%
market['Total_purchases']=market['NumDealsPurchases']+market['NumWebPurchases']+market['NumCatalogPurchases']+market['NumStorePurchases']
market=market.drop(['NumDealsPurchases','NumWebPurchases','NumCatalogPurchases','NumStorePurchases'],axis=1)

# %%
market['veg_products']=market['MntFruits']
market['nonveg_products']=market['MntMeatProducts']+market['MntFishProducts']
market=market.drop(['MntFruits','MntMeatProducts','MntFishProducts'],axis=1)

# %%
market.head()
# Out:
#        Year_Birth   Education Marital_Status   Income Dt_Customer  Recency  \
# ID
# 1826         1970  Graduation       Divorced  84835.0  2014-06-16        0
# 1            1961  Graduation         Single  57091.0  2014-06-15        0
# 10476        1958  Graduation        Married  67267.0  2014-05-13        0
# 1386         1967  Graduation       Together  32474.0  2014-05-11        0
# 5371         1989  Graduation         Single  21474.0  2014-04-08        0
#
#        MntWines  MntSweetProducts  MntGoldProds  NumWebVisitsMonth  Response  \
# ID
# 1826        189               189           218                  1         1
# 1           464                 0            37                  5         1
# 10476       134                 2            30                  2         0
# 1386         10                 0             0                  7         0
# 5371          6                 0            34                  7         1
#
# ...

# %%
sns.barplot(x=market.Marital_Status,y=market.NumWebVisitsMonth)

# %%
market.skew()
# Out:
# Year_Birth           -0.092495
# Income                0.349473
# Recency              -0.004299
# MntWines              1.176036
# MntSweetProducts      2.135674
# MntGoldProds          1.885136
# NumWebVisitsMonth     0.207904
# Response              1.968607
# Complain             10.438160
# Total_Children        0.415519
# Total_purchases       0.250406
# veg_products          2.104241
# nonveg_products       1.750855
# dtype: float64

# %%
sns.distplot(market.skew())

# %%
market.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E97EC24EC8>,
# ...
#       dtype=object)

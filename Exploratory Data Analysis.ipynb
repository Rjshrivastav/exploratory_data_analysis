# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h3>Video Games sales data</h3>

# %%
dataset=pd.read_csv(r'C:\Users\Ranjeet shrivastav\Downloads\data_python\vgsales.csv',index_col=0)

# %%
dataset
# Out:
#                                                    Name Platform    Year  \
# Rank
# 1                                            Wii Sports      Wii  2006.0
# 2                                     Super Mario Bros.      NES  1985.0
# 3                                        Mario Kart Wii      Wii  2008.0
# 4                                     Wii Sports Resort      Wii  2009.0
# 5                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16596                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16597                     Men in Black II: Alien Escape       GC  2003.0
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16599                                        Know How 2       DS  2010.0
# 16600                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16598 entries, 1 to 16600
# Data columns (total 10 columns):
# Name            16598 non-null object
# Platform        16598 non-null object
# Year            16327 non-null float64
# Genre           16598 non-null object
# Publisher       16540 non-null object
# NA_Sales        16598 non-null float64
# EU_Sales        16598 non-null float64
# JP_Sales        16598 non-null float64
# Other_Sales     16598 non-null float64
# Global_Sales    16598 non-null float64
# dtypes: float64(6), object(4)
# memory usage: 1.4+ MB

# %%
dataset.head()
# Out:
#                           Name Platform    Year         Genre Publisher  \
# Rank
# 1                   Wii Sports      Wii  2006.0        Sports  Nintendo
# 2            Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 3               Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 4            Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 5     Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Rank
# 1        41.49     29.02      3.77         8.46         82.74
# 2        29.08      3.58      6.81         0.77         40.24
# 3        15.85     12.88      3.79         3.31         35.82
# 4        15.75     11.01      3.28         2.96         33.00
# 5        11.27      8.89     10.22         1.00         31.37

# %%
dataset.tail()
# Out:
#                                                    Name Platform    Year  \
# Rank
# 16596                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16597                     Men in Black II: Alien Escape       GC  2003.0
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16599                                        Know How 2       DS  2010.0
# 16600                                  Spirits & Spells      GBA  2003.0
#
#           Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# 16596  Platform       Kemco      0.01      0.00       0.0          0.0
# 16597   Shooter  Infogrames      0.01      0.00       0.0          0.0
# 16598    Racing  Activision      0.00      0.00       0.0          0.0
# 16599    Puzzle    7G//AMES      0.00      0.01       0.0          0.0
# 16600  Platform     Wanadoo      0.01      0.00       0.0          0.0
#
#        Global_Sales
# Rank
# 16596          0.01
# 16597          0.01
# ...

# %%
dataset.shape
# Out:
# (16598, 10)

# %%
dataset.describe()
# Out:
#                Year      NA_Sales      EU_Sales      JP_Sales   Other_Sales  \
# count  16327.000000  16598.000000  16598.000000  16598.000000  16598.000000
# mean    2006.406443      0.264667      0.146652      0.077782      0.048063
# std        5.828981      0.816683      0.505351      0.309291      0.188588
# min     1980.000000      0.000000      0.000000      0.000000      0.000000
# 25%     2003.000000      0.000000      0.000000      0.000000      0.000000
# 50%     2007.000000      0.080000      0.020000      0.000000      0.010000
# 75%     2010.000000      0.240000      0.110000      0.040000      0.040000
# max     2020.000000     41.490000     29.020000     10.220000     10.570000
#
#        Global_Sales
# count  16598.000000
# mean       0.537441
# std        1.555028
# min        0.010000
# 25%        0.060000
# 50%        0.170000
# 75%        0.470000
# max       82.740000

# %%
dataset.columns
# Out:
# Index(['Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
dataset.nunique()
# Out:
# Name            11493
# Platform           31
# Year               39
# Genre              12
# Publisher         578
# NA_Sales          409
# EU_Sales          305
# JP_Sales          244
# Other_Sales       157
# Global_Sales      623
# dtype: int64

# %%
dataset['Year'].value_counts()
# Out:
# 2009.0    1431
# 2008.0    1428
# 2010.0    1259
# 2007.0    1202
# 2011.0    1139
# 2006.0    1008
# 2005.0     941
# 2002.0     829
# 2003.0     775
# 2004.0     763
# 2012.0     657
# 2015.0     614
# 2014.0     582
# 2013.0     546
# 2001.0     482
# 1998.0     379
# 2000.0     349
# 2016.0     344
# 1999.0     338
# 1997.0     289
# 1996.0     263
# 1995.0     219
# 1994.0     121
# 1993.0      60
# 1981.0      46
# 1992.0      43
# 1991.0      41
# 1982.0      36
# 1986.0      21
# 1989.0      17
# 1983.0      17
# 1990.0      16
# 1987.0      16
# 1988.0      15
# 1985.0      14
# 1984.0      14
# 1980.0       9
# 2017.0       3
# 2020.0       1
# Name: Year, dtype: int64

# %%
dataset[dataset['Year'].isnull()]
# Out:
#                               Name Platform  Year         Genre  \
# Rank
# 180                Madden NFL 2004      PS2   NaN        Sports
# 378               FIFA Soccer 2004      PS2   NaN        Sports
# 432     LEGO Batman: The Videogame      Wii   NaN        Action
# 471     wwe Smackdown vs. Raw 2006      PS2   NaN      Fighting
# 608                 Space Invaders     2600   NaN       Shooter
# ...                            ...      ...   ...           ...
# 16310                Freaky Flyers       GC   NaN        Racing
# 16330                    Inversion       PC   NaN       Shooter
# 16369  Hakuouki: Shinsengumi Kitan      PS3   NaN     Adventure
# 16430                 Virtua Quest       GC   NaN  Role-Playing
# 16496                   The Smurfs      3DS   NaN        Action
#
#                                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Rank
# 180                           Electronic Arts      4.26      0.26      0.01
# ...

# %%
dataset['Publisher']=dataset['Publisher'].fillna('Unknown')

# %%
dataset['Publisher'].isna().sum()
# Out:
# 0

# %%
dataset=dataset.dropna(how='any')

# %%
dataset[dataset['Year'].isna()].sum()
# Out:
# Name            0.0
# Platform        0.0
# Year            0.0
# Genre           0.0
# Publisher       0.0
# NA_Sales        0.0
# EU_Sales        0.0
# JP_Sales        0.0
# Other_Sales     0.0
# Global_Sales    0.0
# dtype: float64

# %%
dataset
# Out:
#                                                    Name Platform    Year  \
# Rank
# 1                                            Wii Sports      Wii  2006.0
# 2                                     Super Mario Bros.      NES  1985.0
# 3                                        Mario Kart Wii      Wii  2008.0
# 4                                     Wii Sports Resort      Wii  2009.0
# 5                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16596                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16597                     Men in Black II: Alien Escape       GC  2003.0
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16599                                        Know How 2       DS  2010.0
# 16600                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# ...

# %%
game=dataset.drop(['Name','Publisher'],axis=1)

# %%
game
# Out:
#       Platform    Year         Genre  NA_Sales  EU_Sales  JP_Sales  \
# Rank
# 1          Wii  2006.0        Sports     41.49     29.02      3.77
# 2          NES  1985.0      Platform     29.08      3.58      6.81
# 3          Wii  2008.0        Racing     15.85     12.88      3.79
# 4          Wii  2009.0        Sports     15.75     11.01      3.28
# 5           GB  1996.0  Role-Playing     11.27      8.89     10.22
# ...        ...     ...           ...       ...       ...       ...
# 16596      GBA  2002.0      Platform      0.01      0.00      0.00
# 16597       GC  2003.0       Shooter      0.01      0.00      0.00
# 16598      PS2  2008.0        Racing      0.00      0.00      0.00
# 16599       DS  2010.0        Puzzle      0.00      0.01      0.00
# 16600      GBA  2003.0      Platform      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# Rank
# 1             8.46         82.74
# 2             0.77         40.24
# 3             3.31         35.82
# ...

# %%
game.corr()
# Out:
#                   Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Year          1.000000 -0.091402  0.006014 -0.169316     0.041058
# NA_Sales     -0.091402  1.000000  0.768936  0.451285     0.634508
# EU_Sales      0.006014  0.768936  1.000000  0.436414     0.726266
# JP_Sales     -0.169316  0.451285  0.436414  1.000000     0.290653
# Other_Sales   0.041058  0.634508  0.726266  0.290653     1.000000
# Global_Sales -0.074735  0.941268  0.903271  0.612794     0.747974
#
#               Global_Sales
# Year             -0.074735
# NA_Sales          0.941268
# EU_Sales          0.903271
# JP_Sales          0.612794
# Other_Sales       0.747974
# Global_Sales      1.000000

# %%
sns.heatmap(data=game.corr(),annot=False)

# %%
sns.pairplot(game)

# %%
game['NA_Sales']
# Out:
# Rank
# 1        41.49
# 2        29.08
# 3        15.85
# 4        15.75
# 5        11.27
#          ...
# 16596     0.01
# 16597     0.01
# 16598     0.00
# 16599     0.00
# 16600     0.01
# Name: NA_Sales, Length: 16327, dtype: float64

# %%
sns.relplot(x='Global_Sales',y='JP_Sales',hue='Genre',data=game)

# %%
sns.distplot(game['NA_Sales'])

# %%
sns.catplot(x='JP_Sales',kind='box',data=game)

# %%
game['JP_Sales'].mean()
# Out:
# 0.07866111349298115

# %%
fig,axes=plt.subplots(1,5,figsize=(12,6),sharey=True)
sns.kdeplot(ax=axes[0],data=game['NA_Sales'],shade=True)
axes[0].set_title('NA_sales')

sns.kdeplot(ax=axes[1],data=game['EU_Sales'],shade=True)
axes[1].set_title('EU_Sales')

sns.kdeplot(ax=axes[2],data=game['JP_Sales'],shade=True)
axes[2].set_title('JP_Sales')

sns.kdeplot(ax=axes[3],data=game['Other_Sales'],shade=True)
axes[3].set_title('Other_Sales')

sns.kdeplot(ax=axes[4],data=game['Global_Sales'],shade=True)
axes[4].set_title('Global_Sales')
# Out:
# Text(0.5, 1.0, 'Global_Sales')
